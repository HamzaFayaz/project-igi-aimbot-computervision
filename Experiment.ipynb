# %%
import numpy as np
import cv2
import mss
import torch
from time import time
import time
from ultralytics import YOLO
from datetime import datetime
import os
import win32api
import win32con
from math import sqrt
import supervision as sv

class GameDetector:
    def __init__(self, model_path):
        # Model initialization
        self.model = YOLO(model_path)
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'
        print(f"Using device: {self.device}")
        
        # Screen capture setup
        self.sct = mss.mss()
        self.monitor = {'top': 0, 'left': 0, 'width': 1920, 'height': 1080}
        
        # ByteTrack initialization with proper components
        self.tracker = sv.ByteTrack()
        self.box_annotator = sv.BoundingBoxAnnotator()
        self.label_annotator = sv.LabelAnnotator()
        
        # Tracking settings
        self.detection_threshold = 0.6
        self.tracked_objects = []
        
        # Aim settings
        self.aim_enabled = False
        self.target_lock = False
        self.screen_center = (self.monitor['width'] // 2, self.monitor['height'] // 2)
        self.aim_threshold = 40
        self.shot_cooldown = 0.1
        self.last_shot_time = 0
        self.shot_count = 0
        self.aim_smoothing = 0.2
        self.last_aim_pos = self.screen_center
        self.mouse_sensitivity = 0.7
        
        # Recording setup
        os.makedirs('recordings', exist_ok=True)
        self.setup_video_writer()

    def process_frame(self, frame):
        # Run YOLO detection
        results = self.model(frame, device=self.device)[0]
        
        # Convert YOLO results to supervision Detections
        detections = sv.Detections.from_ultralytics(results)
        
        # Filter detections based on confidence
        mask = detections.confidence >= self.detection_threshold
        detections = detections[mask]
        
        # Update tracks using ByteTrack
        tracked_detections = self.tracker.update_with_detections(detections)
        
        # Create copy of frame for annotation
        annotated_frame = frame.copy()
        
        # Process tracked objects
        best_target = None
        min_distance = float('inf')
        
        if len(tracked_detections) > 0:
            # Create labels for visualization
            labels = [f"#{track_id}" for track_id in tracked_detections.tracker_id]
            
            # Draw bounding boxes and labels
            annotated_frame = self.box_annotator.annotate(
                scene=annotated_frame,
                detections=tracked_detections
            )
            
            annotated_frame = self.label_annotator.annotate(
                scene=annotated_frame,
                detections=tracked_detections,
                labels=labels
            )
            
            # Process each detection for targeting
            for i in range(len(tracked_detections)):
                xyxy = tracked_detections.xyxy[i]
                class_id = tracked_detections.class_id[i]
                class_name = self.model.names[class_id]
                x1, y1, x2, y2 = map(int, xyxy)
                
                # Calculate distance for enemy class only
                if class_name.lower() == 'enemy':
                    target_center = ((x1 + x2) // 2, (y1 + y2) // 2)
                    distance = self.calculate_distance(target_center, self.screen_center)
                    
                    if distance < min_distance:
                        min_distance = distance
                        best_target = (x1, y1, x2, y2, class_name)
        
        # Handle aiming if we have a valid target
        if best_target and self.aim_enabled:
            self.aim_at_target(best_target[:4], best_target[4])
            
        return annotated_frame

    def calculate_distance(self, point1, point2):
        return sqrt((point1[0] - point2[0])**2 + (point1[1] - point2[1])**2)
    
    def move_mouse_relative(self, dx, dy):
        scaled_dx = int(dx * self.mouse_sensitivity)
        scaled_dy = int(dy * self.mouse_sensitivity)
        max_move = 50
        scaled_dx = max(min(scaled_dx, max_move), -max_move)
        scaled_dy = max(min(scaled_dy, max_move), -max_move)
        win32api.mouse_event(win32con.MOUSEEVENTF_MOVE, scaled_dx, scaled_dy, 0, 0)
    
    def shoot(self):
        current_time = time.time()
        if current_time - self.last_shot_time >= self.shot_cooldown:
            win32api.mouse_event(win32con.MOUSEEVENTF_LEFTDOWN, 0, 0, 0, 0)
            time.sleep(0.02)
            win32api.mouse_event(win32con.MOUSEEVENTF_LEFTUP, 0, 0, 0, 0)
            self.last_shot_time = current_time
            self.shot_count += 1
            return True
        return False
    
    def aim_at_target(self, target_pos, target_class):
        if not self.aim_enabled or target_class.lower() != 'enemy':
            return False
            
        target_x = (target_pos[0] + target_pos[2]) // 2
        target_y = (target_pos[1] + target_pos[3]) // 2
        
        dx = target_x - self.screen_center[0]
        dy = target_y - self.screen_center[1]
        
        smooth_dx = int(dx * self.aim_smoothing)
        smooth_dy = int(dy * self.aim_smoothing)
        
        if abs(dx) > 5 or abs(dy) > 5:
            self.move_mouse_relative(smooth_dx, smooth_dy)
        
        distance = sqrt(dx*dx + dy*dy)
        if distance <= self.aim_threshold and self.target_lock:
            return self.shoot()
        
        return False

    def setup_video_writer(self):
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        self.filename = os.path.join('recordings', f'game_detection_{timestamp}.avi')
        fourcc = cv2.VideoWriter_fourcc(*'XVID')
        self.out = cv2.VideoWriter(
            self.filename,
            fourcc,
            30.0,
            (self.monitor['width'], self.monitor['height'])
        )
        print(f"Recording to {self.filename}")
    
    def capture_screen(self):
        screenshot = np.array(self.sct.grab(self.monitor))
        return cv2.cvtColor(screenshot, cv2.COLOR_BGRA2BGR)
    
    def run_detection(self):
        frames_written = 0
        fps_history = []
        
        try:
            while True:
                start_time = time.time()
                frame = self.capture_screen()
                processed_frame = self.process_frame(frame)
                
                fps = 1 / (time.time() - start_time)
                fps_history.append(fps)
                if len(fps_history) > 20:
                    fps_history.pop(0)
                avg_fps = sum(fps_history) / len(fps_history)
                
                # cv2.putText(processed_frame, f'FPS: {int(avg_fps)}', (20, 70),
                #            cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
                
                self.out.write(processed_frame)
                frames_written += 1
                
                cv2.imshow('Game Detection', processed_frame)
                
                key = cv2.waitKey(1) & 0xFF
                if key == ord('q'):
                    break
                elif key == ord('f'):
                    self.aim_enabled = not self.aim_enabled
                    print(f"Aim {'enabled' if self.aim_enabled else 'disabled'}")
                elif key == ord('l'):
                    self.target_lock = not self.target_lock
                    print(f"Target lock {'enabled' if self.target_lock else 'disabled'}")
        
        except Exception as e:
            print(f"Error during detection: {str(e)}")
        finally:
            print(f"Saving video... ({frames_written} frames written)")
            self.out.release()
            self.sct.close()
            cv2.destroyAllWindows()
            
            if os.path.exists(self.filename):
                size_mb = os.path.getsize(self.filename) / (1024 * 1024)
                print(f"Video file size: {size_mb:.2f} MB")
            else:
                print("Warning: Video file was not created!")

if __name__ == "__main__":
    try:
        detector = GameDetector('best.pt')
        detector.run_detection()
    except Exception as e:
        print(f"Error: {str(e)}")
# Out:
# Using device: cuda
# Recording to recordings\game_detection_20250617_115643.avi
# SupervisionWarnings: BoundingBoxAnnotator is deprecated: `BoundingBoxAnnotator` is deprecated and has been renamed to `BoxAnnotator`. `BoundingBoxAnnotator` will be removed in supervision-0.26.0.
# 0: 384x640 (no detections), 43.1ms
# Speed: 2.0ms preprocess, 43.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 157.7ms
# Speed: 5.4ms preprocess, 157.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.6ms
# Speed: 2.6ms preprocess, 43.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.5ms
# Speed: 2.0ms preprocess, 42.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.6ms
# Speed: 1.9ms preprocess, 41.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.6ms
# Speed: 2.9ms preprocess, 41.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.9ms
# Speed: 3.0ms preprocess, 40.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.4ms
# Speed: 3.1ms preprocess, 41.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.7ms
# Speed: 2.6ms preprocess, 39.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.4ms
# Speed: 2.7ms preprocess, 40.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.3ms
# Speed: 2.0ms preprocess, 40.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.8ms
# Speed: 2.0ms preprocess, 40.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.1ms
# Speed: 2.1ms preprocess, 40.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.8ms
# Speed: 2.9ms preprocess, 39.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.8ms
# Speed: 2.0ms preprocess, 39.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.3ms
# Speed: 2.7ms preprocess, 49.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 48.5ms
# Speed: 3.2ms preprocess, 48.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 42.0ms
# Speed: 1.9ms preprocess, 42.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 42.2ms
# Speed: 3.0ms preprocess, 42.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 42.1ms
# Speed: 2.6ms preprocess, 42.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 39.3ms
# Speed: 3.3ms preprocess, 39.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 40.1ms
# Speed: 2.3ms preprocess, 40.1ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 39.3ms
# Speed: 2.7ms preprocess, 39.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 40.4ms
# Speed: 2.0ms preprocess, 40.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 40.7ms
# Speed: 3.5ms preprocess, 40.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 40.0ms
# Speed: 2.3ms preprocess, 40.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 39.9ms
# Speed: 3.0ms preprocess, 39.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 40.2ms
# Speed: 2.2ms preprocess, 40.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 39.7ms
# Speed: 3.0ms preprocess, 39.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 40.6ms
# Speed: 5.8ms preprocess, 40.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 40.1ms
# Speed: 4.0ms preprocess, 40.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 122.1ms
# Speed: 7.2ms preprocess, 122.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 87.1ms
# Speed: 5.9ms preprocess, 87.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 50.2ms
# Speed: 2.0ms preprocess, 50.2ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 116.1ms
# Speed: 6.7ms preprocess, 116.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 48.8ms
# Speed: 5.6ms preprocess, 48.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 41.6ms
# Speed: 4.5ms preprocess, 41.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 41.4ms
# Speed: 4.1ms preprocess, 41.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 42.6ms
# Speed: 3.0ms preprocess, 42.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 43.0ms
# Speed: 3.2ms preprocess, 43.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 42.0ms
# Speed: 3.5ms preprocess, 42.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 43.6ms
# Speed: 4.4ms preprocess, 43.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 42.1ms
# Speed: 5.2ms preprocess, 42.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 41.3ms
# Speed: 4.9ms preprocess, 41.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 40.0ms
# Speed: 4.9ms preprocess, 40.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 40.7ms
# Speed: 4.9ms preprocess, 40.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 40.3ms
# Speed: 4.4ms preprocess, 40.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 144.0ms
# Speed: 7.0ms preprocess, 144.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.0ms
# Speed: 1.9ms preprocess, 44.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 125.9ms
# Speed: 5.0ms preprocess, 125.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.7ms
# Speed: 3.0ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 142.9ms
# Speed: 5.6ms preprocess, 142.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.5ms
# Speed: 2.0ms preprocess, 43.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 147.0ms
# Speed: 8.5ms preprocess, 147.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 95.0ms
# Speed: 6.6ms preprocess, 95.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.6ms
# Speed: 3.1ms preprocess, 48.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.5ms
# Speed: 2.6ms preprocess, 41.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 187.9ms
# Speed: 4.4ms preprocess, 187.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.8ms
# Speed: 3.7ms preprocess, 42.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 152.0ms
# Speed: 7.8ms preprocess, 152.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.1ms
# Speed: 3.5ms preprocess, 44.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.8ms
# Speed: 3.5ms preprocess, 41.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 172.7ms
# Speed: 2.5ms preprocess, 172.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.7ms
# Speed: 2.0ms preprocess, 43.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.0ms
# Speed: 2.7ms preprocess, 42.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.5ms
# Speed: 3.9ms preprocess, 42.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.8ms
# Speed: 3.5ms preprocess, 42.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.8ms
# Speed: 2.0ms preprocess, 41.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.3ms
# Speed: 3.0ms preprocess, 41.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.6ms
# Speed: 1.9ms preprocess, 41.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.3ms
# Speed: 2.0ms preprocess, 41.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.2ms
# Speed: 3.0ms preprocess, 41.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.3ms
# Speed: 3.0ms preprocess, 39.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.3ms
# Speed: 3.0ms preprocess, 39.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.2ms
# Speed: 3.0ms preprocess, 39.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 131.3ms
# Speed: 8.0ms preprocess, 131.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 92.1ms
# Speed: 7.4ms preprocess, 92.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.5ms
# Speed: 3.0ms preprocess, 42.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.7ms
# Speed: 4.3ms preprocess, 40.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 188.5ms
# Speed: 4.9ms preprocess, 188.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.2ms
# Speed: 1.9ms preprocess, 43.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.6ms
# Speed: 3.0ms preprocess, 42.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.4ms
# Speed: 2.6ms preprocess, 42.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.3ms
# Speed: 2.0ms preprocess, 39.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.3ms
# Speed: 3.0ms preprocess, 40.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.3ms
# Speed: 2.0ms preprocess, 40.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.4ms
# Speed: 2.9ms preprocess, 39.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.0ms
# Speed: 2.0ms preprocess, 41.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.3ms
# Speed: 2.0ms preprocess, 40.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.2ms
# Speed: 2.0ms preprocess, 40.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.5ms
# Speed: 3.0ms preprocess, 40.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.6ms
# Speed: 2.0ms preprocess, 39.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 80.2ms
# Speed: 7.0ms preprocess, 80.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.2ms
# Speed: 1.9ms preprocess, 49.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.1ms
# Speed: 3.0ms preprocess, 41.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.1ms
# Speed: 2.9ms preprocess, 41.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.3ms
# Speed: 2.2ms preprocess, 42.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.8ms
# Speed: 1.9ms preprocess, 40.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.1ms
# Speed: 2.9ms preprocess, 40.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.8ms
# Speed: 3.0ms preprocess, 39.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.1ms
# Speed: 2.9ms preprocess, 39.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.3ms
# Speed: 3.0ms preprocess, 41.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.9ms
# Speed: 2.9ms preprocess, 39.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.6ms
# Speed: 2.9ms preprocess, 39.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.1ms
# Speed: 1.9ms preprocess, 40.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.0ms
# Speed: 2.0ms preprocess, 40.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.1ms
# Speed: 2.0ms preprocess, 40.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.7ms
# Speed: 2.0ms preprocess, 39.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.2ms
# Speed: 3.0ms preprocess, 40.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.4ms
# Speed: 1.9ms preprocess, 40.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.6ms
# Speed: 2.3ms preprocess, 40.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.7ms
# Speed: 3.4ms preprocess, 40.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.7ms
# Speed: 2.0ms preprocess, 40.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 171.3ms
# Speed: 5.9ms preprocess, 171.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.2ms
# Speed: 3.0ms preprocess, 43.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.3ms
# Speed: 3.0ms preprocess, 43.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.6ms
# Speed: 2.0ms preprocess, 41.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.1ms
# Speed: 3.0ms preprocess, 42.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.5ms
# Speed: 3.0ms preprocess, 40.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 58.2ms
# Speed: 6.7ms preprocess, 58.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.9ms
# Speed: 6.2ms preprocess, 71.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.5ms
# Speed: 3.0ms preprocess, 48.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 123.1ms
# Speed: 5.2ms preprocess, 123.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.8ms
# Speed: 3.4ms preprocess, 88.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 81.6ms
# Speed: 7.0ms preprocess, 81.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 74.1ms
# Speed: 6.2ms preprocess, 74.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 78.3ms
# Speed: 3.0ms preprocess, 78.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 83.5ms
# Speed: 5.1ms preprocess, 83.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.1ms
# Speed: 3.0ms preprocess, 48.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 112.1ms
# Speed: 5.2ms preprocess, 112.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 85.5ms
# Speed: 6.1ms preprocess, 85.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.2ms
# Speed: 3.3ms preprocess, 49.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.4ms
# Speed: 2.8ms preprocess, 41.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.8ms
# Speed: 3.0ms preprocess, 40.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 85.9ms
# Speed: 6.3ms preprocess, 85.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.2ms
# Speed: 2.9ms preprocess, 48.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.0ms
# Speed: 2.0ms preprocess, 42.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.6ms
# Speed: 2.0ms preprocess, 41.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.0ms
# Speed: 2.4ms preprocess, 41.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.4ms
# Speed: 2.0ms preprocess, 40.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.0ms
# Speed: 2.6ms preprocess, 40.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.6ms
# Speed: 2.4ms preprocess, 39.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.6ms
# Speed: 2.3ms preprocess, 40.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Aim enabled
#
# 0: 384x640 (no detections), 40.0ms
# Speed: 2.0ms preprocess, 40.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.0ms
# Speed: 1.7ms preprocess, 41.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.2ms
# Speed: 2.9ms preprocess, 39.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.0ms
# Speed: 3.0ms preprocess, 40.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.3ms
# Speed: 2.0ms preprocess, 40.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.0ms
# Speed: 3.0ms preprocess, 39.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.4ms
# Speed: 2.3ms preprocess, 40.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.3ms
# Speed: 3.3ms preprocess, 40.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Target lock enabled
#
# 0: 384x640 (no detections), 39.3ms
# Speed: 3.0ms preprocess, 39.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.0ms
# Speed: 2.8ms preprocess, 39.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.9ms
# Speed: 2.4ms preprocess, 39.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.5ms
# Speed: 2.6ms preprocess, 40.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.8ms
# Speed: 4.5ms preprocess, 39.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.9ms
# Speed: 3.0ms preprocess, 39.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.4ms
# Speed: 3.1ms preprocess, 39.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.5ms
# Speed: 2.0ms preprocess, 40.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.8ms
# Speed: 3.0ms preprocess, 40.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.9ms
# Speed: 3.1ms preprocess, 39.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.5ms
# Speed: 2.8ms preprocess, 40.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.4ms
# Speed: 3.0ms preprocess, 40.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.9ms
# Speed: 2.0ms preprocess, 40.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.2ms
# Speed: 2.1ms preprocess, 41.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.3ms
# Speed: 2.9ms preprocess, 40.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.8ms
# Speed: 2.0ms preprocess, 41.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.5ms
# Speed: 3.0ms preprocess, 41.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.3ms
# Speed: 2.2ms preprocess, 41.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.2ms
# Speed: 2.0ms preprocess, 42.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.6ms
# Speed: 3.0ms preprocess, 40.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.8ms
# Speed: 3.9ms preprocess, 41.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.6ms
# Speed: 2.0ms preprocess, 41.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.1ms
# Speed: 4.0ms preprocess, 54.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 181.7ms
# Speed: 9.0ms preprocess, 181.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 70.6ms
# Speed: 8.2ms preprocess, 70.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 63.0ms
# Speed: 7.0ms preprocess, 63.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 55.5ms
# Speed: 7.4ms preprocess, 55.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 69.4ms
# Speed: 8.1ms preprocess, 69.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 62.1ms
# Speed: 7.3ms preprocess, 62.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 68.2ms
# Speed: 6.4ms preprocess, 68.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 69.8ms
# Speed: 8.4ms preprocess, 69.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 73.6ms
# Speed: 4.8ms preprocess, 73.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Enemys, 1 Sam, 72.8ms
# Speed: 7.1ms preprocess, 72.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.9ms
# Speed: 7.3ms preprocess, 57.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 60.2ms
# Speed: 8.4ms preprocess, 60.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 60.7ms
# Speed: 7.9ms preprocess, 60.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 64.0ms
# Speed: 8.1ms preprocess, 64.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 66.2ms
# Speed: 6.6ms preprocess, 66.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 52.6ms
# Speed: 8.4ms preprocess, 52.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 65.2ms
# Speed: 7.8ms preprocess, 65.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 65.5ms
# Speed: 7.4ms preprocess, 65.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 69.7ms
# Speed: 7.1ms preprocess, 69.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 52.0ms
# Speed: 5.0ms preprocess, 52.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 53.6ms
# Speed: 4.4ms preprocess, 53.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 156.4ms
# Speed: 8.1ms preprocess, 156.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 74.5ms
# Speed: 8.0ms preprocess, 74.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 53.3ms
# Speed: 5.0ms preprocess, 53.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 143.6ms
# Speed: 7.3ms preprocess, 143.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 53.6ms
# Speed: 8.0ms preprocess, 53.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 51.2ms
# Speed: 4.9ms preprocess, 51.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 59.6ms
# Speed: 5.9ms preprocess, 59.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 71.7ms
# Speed: 7.0ms preprocess, 71.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 74.2ms
# Speed: 9.0ms preprocess, 74.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 76.4ms
# Speed: 7.0ms preprocess, 76.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 59.7ms
# Speed: 7.0ms preprocess, 59.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 63.3ms
# Speed: 7.7ms preprocess, 63.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 62.8ms
# Speed: 8.3ms preprocess, 62.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 65.0ms
# Speed: 7.0ms preprocess, 65.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 63.4ms
# Speed: 8.0ms preprocess, 63.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 67.4ms
# Speed: 7.5ms preprocess, 67.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 66.3ms
# Speed: 8.3ms preprocess, 66.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 66.7ms
# Speed: 7.8ms preprocess, 66.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 69.2ms
# Speed: 8.7ms preprocess, 69.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 67.6ms
# Speed: 7.3ms preprocess, 67.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 70.3ms
# Speed: 8.0ms preprocess, 70.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 58.4ms
# Speed: 10.9ms preprocess, 58.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 59.0ms
# Speed: 8.1ms preprocess, 59.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 64.2ms
# Speed: 7.3ms preprocess, 64.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 66.6ms
# Speed: 6.5ms preprocess, 66.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 69.5ms
# Speed: 7.6ms preprocess, 69.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 64.8ms
# Speed: 7.8ms preprocess, 64.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 62.0ms
# Speed: 9.1ms preprocess, 62.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 67.0ms
# Speed: 9.6ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 67.7ms
# Speed: 6.7ms preprocess, 67.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 72.3ms
# Speed: 7.8ms preprocess, 72.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 72.3ms
# Speed: 7.9ms preprocess, 72.3ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 74.6ms
# Speed: 6.0ms preprocess, 74.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 76.6ms
# Speed: 7.2ms preprocess, 76.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 76.2ms
# Speed: 9.2ms preprocess, 76.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 51.7ms
# Speed: 8.4ms preprocess, 51.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 67.4ms
# Speed: 6.8ms preprocess, 67.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 51.2ms
# Speed: 6.0ms preprocess, 51.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 97.4ms
# Speed: 8.0ms preprocess, 97.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 50.5ms
# Speed: 5.8ms preprocess, 50.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 100.6ms
# Speed: 7.9ms preprocess, 100.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 70.7ms
# Speed: 8.0ms preprocess, 70.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 73.2ms
# Speed: 7.1ms preprocess, 73.2ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 52.5ms
# Speed: 5.1ms preprocess, 52.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 51.9ms
# Speed: 5.2ms preprocess, 51.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 51.5ms
# Speed: 8.1ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 70.4ms
# Speed: 7.2ms preprocess, 70.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 54.9ms
# Speed: 7.9ms preprocess, 54.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 55.3ms
# Speed: 8.4ms preprocess, 55.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 71.9ms
# Speed: 7.8ms preprocess, 71.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 55.3ms
# Speed: 7.0ms preprocess, 55.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 59.9ms
# Speed: 8.2ms preprocess, 59.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 63.3ms
# Speed: 7.6ms preprocess, 63.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 52.4ms
# Speed: 4.0ms preprocess, 52.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Sams, 52.3ms
# Speed: 4.6ms preprocess, 52.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.7ms
# Speed: 3.7ms preprocess, 51.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.4ms
# Speed: 6.3ms preprocess, 52.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.3ms
# Speed: 9.2ms preprocess, 53.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.9ms
# Speed: 8.3ms preprocess, 69.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.1ms
# Speed: 5.0ms preprocess, 51.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.5ms
# Speed: 4.5ms preprocess, 51.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 63.3ms
# Speed: 7.7ms preprocess, 63.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 65.7ms
# Speed: 6.4ms preprocess, 65.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 62.1ms
# Speed: 8.0ms preprocess, 62.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 63.8ms
# Speed: 8.3ms preprocess, 63.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.6ms
# Speed: 4.0ms preprocess, 51.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 61.7ms
# Speed: 7.5ms preprocess, 61.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.8ms
# Speed: 7.4ms preprocess, 68.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.8ms
# Speed: 7.1ms preprocess, 67.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.6ms
# Speed: 7.0ms preprocess, 55.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.4ms
# Speed: 7.5ms preprocess, 57.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 62.2ms
# Speed: 7.8ms preprocess, 62.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 77.4ms
# Speed: 8.5ms preprocess, 77.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 79.1ms
# Speed: 6.8ms preprocess, 79.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 80.8ms
# Speed: 6.0ms preprocess, 80.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 65.8ms
# Speed: 7.0ms preprocess, 65.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 64.7ms
# Speed: 8.4ms preprocess, 64.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.4ms
# Speed: 7.5ms preprocess, 55.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.3ms
# Speed: 7.4ms preprocess, 55.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 76.1ms
# Speed: 4.9ms preprocess, 76.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.7ms
# Speed: 3.9ms preprocess, 51.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 85.9ms
# Speed: 9.2ms preprocess, 85.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 76.7ms
# Speed: 6.8ms preprocess, 76.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.3ms
# Speed: 4.7ms preprocess, 50.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 93.7ms
# Speed: 6.3ms preprocess, 93.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 79.5ms
# Speed: 6.5ms preprocess, 79.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.5ms
# Speed: 6.4ms preprocess, 69.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.0ms
# Speed: 6.9ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.5ms
# Speed: 6.6ms preprocess, 71.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 58.5ms
# Speed: 6.3ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 56.7ms
# Speed: 7.5ms preprocess, 56.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 58.6ms
# Speed: 7.3ms preprocess, 58.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 61.4ms
# Speed: 7.8ms preprocess, 61.4ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 52.5ms
# Speed: 5.0ms preprocess, 52.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 52.1ms
# Speed: 5.9ms preprocess, 52.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 56.3ms
# Speed: 6.9ms preprocess, 56.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 65.7ms
# Speed: 8.5ms preprocess, 65.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 69.4ms
# Speed: 6.6ms preprocess, 69.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 70.1ms
# Speed: 9.8ms preprocess, 70.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 56.3ms
# Speed: 7.2ms preprocess, 56.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 51.7ms
# Speed: 5.8ms preprocess, 51.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 152.6ms
# Speed: 8.9ms preprocess, 152.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 77.0ms
# Speed: 8.4ms preprocess, 77.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 52.6ms
# Speed: 8.1ms preprocess, 52.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 63.5ms
# Speed: 7.0ms preprocess, 63.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 51.9ms
# Speed: 5.3ms preprocess, 51.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 51.1ms
# Speed: 4.8ms preprocess, 51.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 152.1ms
# Speed: 8.0ms preprocess, 152.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 72.8ms
# Speed: 8.1ms preprocess, 72.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 52.0ms
# Speed: 4.0ms preprocess, 52.0ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 157.2ms
# Speed: 7.3ms preprocess, 157.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 62.9ms
# Speed: 7.9ms preprocess, 62.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 52.9ms
# Speed: 9.2ms preprocess, 52.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 50.9ms
# Speed: 7.0ms preprocess, 50.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 51.7ms
# Speed: 5.9ms preprocess, 51.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.8ms
# Speed: 4.5ms preprocess, 51.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.7ms
# Speed: 6.5ms preprocess, 54.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.9ms
# Speed: 8.3ms preprocess, 53.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.2ms
# Speed: 8.7ms preprocess, 57.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 61.0ms
# Speed: 7.0ms preprocess, 61.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 52.8ms
# Speed: 6.7ms preprocess, 52.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 67.8ms
# Speed: 8.1ms preprocess, 67.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 54.6ms
# Speed: 6.9ms preprocess, 54.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 56.1ms
# Speed: 7.5ms preprocess, 56.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 70.1ms
# Speed: 8.3ms preprocess, 70.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 59.2ms
# Speed: 7.8ms preprocess, 59.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 60.0ms
# Speed: 7.9ms preprocess, 60.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Enemy, 1 Sam, 65.9ms
# Speed: 6.8ms preprocess, 65.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 65.4ms
# Speed: 6.0ms preprocess, 65.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 63.1ms
# Speed: 7.5ms preprocess, 63.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 62.6ms
# Speed: 7.2ms preprocess, 62.6ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 72.4ms
# Speed: 9.1ms preprocess, 72.4ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 51.4ms
# Speed: 7.5ms preprocess, 51.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 68.2ms
# Speed: 7.3ms preprocess, 68.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 72.4ms
# Speed: 7.5ms preprocess, 72.4ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 68.6ms
# Speed: 7.0ms preprocess, 68.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 63.0ms
# Speed: 7.9ms preprocess, 63.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 63.3ms
# Speed: 7.7ms preprocess, 63.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 61.3ms
# Speed: 7.0ms preprocess, 61.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 61.5ms
# Speed: 7.2ms preprocess, 61.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.3ms
# Speed: 6.1ms preprocess, 69.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 77.6ms
# Speed: 8.5ms preprocess, 77.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.8ms
# Speed: 9.1ms preprocess, 67.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.5ms
# Speed: 8.4ms preprocess, 67.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.4ms
# Speed: 7.5ms preprocess, 69.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.6ms
# Speed: 3.0ms preprocess, 51.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.8ms
# Speed: 3.0ms preprocess, 52.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 58.5ms
# Speed: 8.3ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 62.7ms
# Speed: 6.1ms preprocess, 62.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 65.0ms
# Speed: 8.4ms preprocess, 65.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 62.9ms
# Speed: 8.6ms preprocess, 62.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.2ms
# Speed: 4.0ms preprocess, 49.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 96.7ms
# Speed: 7.1ms preprocess, 96.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.1ms
# Speed: 7.2ms preprocess, 71.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.2ms
# Speed: 8.3ms preprocess, 68.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 58.2ms
# Speed: 9.0ms preprocess, 58.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.0ms
# Speed: 7.7ms preprocess, 56.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.8ms
# Speed: 6.1ms preprocess, 57.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 75.5ms
# Speed: 6.4ms preprocess, 75.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.7ms
# Speed: 6.2ms preprocess, 54.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.2ms
# Speed: 8.6ms preprocess, 54.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 65.8ms
# Speed: 8.5ms preprocess, 65.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.3ms
# Speed: 7.3ms preprocess, 71.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 71.6ms
# Speed: 6.5ms preprocess, 71.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 76.4ms
# Speed: 7.4ms preprocess, 76.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 58.6ms
# Speed: 7.4ms preprocess, 58.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 74.8ms
# Speed: 8.0ms preprocess, 74.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 74.1ms
# Speed: 5.7ms preprocess, 74.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.4ms
# Speed: 8.5ms preprocess, 52.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 66.0ms
# Speed: 7.0ms preprocess, 66.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.0ms
# Speed: 8.0ms preprocess, 68.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.5ms
# Speed: 8.3ms preprocess, 55.5ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.8ms
# Speed: 9.4ms preprocess, 55.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 73.0ms
# Speed: 6.1ms preprocess, 73.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 75.2ms
# Speed: 6.5ms preprocess, 75.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 63.6ms
# Speed: 7.2ms preprocess, 63.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.3ms
# Speed: 7.5ms preprocess, 52.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.6ms
# Speed: 5.4ms preprocess, 51.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.8ms
# Speed: 6.2ms preprocess, 50.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 58.7ms
# Speed: 5.3ms preprocess, 58.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 60.8ms
# Speed: 6.1ms preprocess, 60.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 58.8ms
# Speed: 7.9ms preprocess, 58.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 59.4ms
# Speed: 7.8ms preprocess, 59.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 52.5ms
# Speed: 4.5ms preprocess, 52.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Sams, 61.4ms
# Speed: 9.0ms preprocess, 61.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 70.7ms
# Speed: 5.8ms preprocess, 70.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 67.7ms
# Speed: 6.9ms preprocess, 67.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 71.6ms
# Speed: 5.0ms preprocess, 71.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Sam, 69.0ms
# Speed: 7.7ms preprocess, 69.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Sams, 68.5ms
# Speed: 7.0ms preprocess, 68.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Sams, 71.5ms
# Speed: 6.9ms preprocess, 71.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Sams, 49.6ms
# Speed: 4.0ms preprocess, 49.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Sams, 47.7ms
# Speed: 5.0ms preprocess, 47.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Sams, 261.0ms
# Speed: 7.0ms preprocess, 261.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.0ms
# Speed: 3.0ms preprocess, 45.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 120.2ms
# Speed: 8.0ms preprocess, 120.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.9ms
# Speed: 6.9ms preprocess, 70.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.5ms
# Speed: 6.9ms preprocess, 57.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 78.0ms
# Speed: 6.6ms preprocess, 78.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 74.6ms
# Speed: 6.5ms preprocess, 74.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.3ms
# Speed: 2.0ms preprocess, 41.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.3ms
# Speed: 2.9ms preprocess, 40.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.2ms
# Speed: 2.3ms preprocess, 39.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.3ms
# Speed: 2.0ms preprocess, 40.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.4ms
# Speed: 2.8ms preprocess, 42.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.9ms
# Speed: 3.1ms preprocess, 42.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.5ms
# Speed: 3.0ms preprocess, 42.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.8ms
# Speed: 4.0ms preprocess, 42.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.6ms
# Speed: 3.1ms preprocess, 42.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.4ms
# Speed: 3.1ms preprocess, 42.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 140.2ms
# Speed: 7.1ms preprocess, 140.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.0ms
# Speed: 3.2ms preprocess, 52.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 79.3ms
# Speed: 6.6ms preprocess, 79.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.9ms
# Speed: 4.0ms preprocess, 51.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.9ms
# Speed: 3.0ms preprocess, 41.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 169.8ms
# Speed: 6.4ms preprocess, 169.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 84.6ms
# Speed: 6.0ms preprocess, 84.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 64.8ms
# Speed: 7.0ms preprocess, 64.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.2ms
# Speed: 3.0ms preprocess, 52.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.7ms
# Speed: 1.9ms preprocess, 41.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.2ms
# Speed: 2.0ms preprocess, 41.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.8ms
# Speed: 2.9ms preprocess, 41.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.4ms
# Speed: 2.9ms preprocess, 39.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.4ms
# Speed: 2.1ms preprocess, 39.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.8ms
# Speed: 2.0ms preprocess, 40.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.3ms
# Speed: 2.0ms preprocess, 40.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 42.3ms
# Speed: 2.0ms preprocess, 42.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.0ms
# Speed: 4.9ms preprocess, 43.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.7ms
# Speed: 4.6ms preprocess, 51.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.3ms
# Speed: 3.6ms preprocess, 51.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.2ms
# Speed: 2.0ms preprocess, 45.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.2ms
# Speed: 3.0ms preprocess, 46.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saving video... (427 frames written)
# Video file size: 19.25 MB
